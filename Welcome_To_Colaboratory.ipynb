# %% [markdown]
# <a href="https://colab.research.google.com/github/Atulsingh7/DealersData/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
df_bikes = pd.read_csv('/content/bikes.csv')
df_dealers = pd.read_csv('/content/output.csv')
# Out:
# <ipython-input-301-1386c8c55caf>:2: DtypeWarning: Columns (21,27,28,37,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dealers = pd.read_csv('/content/output.csv')

# %%
# Removing the nan values of Dealer Code and Cust ID 

df_dealers = df_dealers[df_dealers['Dealer Code'].notna()]
df_bikes = df_bikes[df_bikes['Customer Id'].notna()]

# %%
set_dealers = set(df_dealers['Email Id'].tolist())
set_bikes = set(df_bikes['Customer Email Id'].tolist())

# %%
# set Intersection of Emails 

intersection_email = set_dealers.intersection(set_bikes)
intersection_email
# Out:
# {'aaa@gmail.com', 'ayyampettai@baluhonda.com', nan, 'viju.ptel@gmail.com'}

# %%
dataFrame3 = df_bikes.loc[df_bikes['Customer Email Id'] == 'viju.ptel@gmail.com']
dataFrame3
# Out:
#         Region Model Name Type Customer Id Customer First Name  \
# 84704  Central   CB SHINE   ID   1-2G7HMJ7              PUNAJI
#
#       Customer Last Name     Customer Type Customer Category  \
# 84704           KHEDEKAR  First Time Buyer        Individual
#
#                         Customer Address Line 1 Customer Address Line 2  ...  \
# 84704  71 , VILL. MACHALPUR BUJURG TAH MAHESWER                     NaN  ...
#
#       Invoice Number                Reference No Invoice Created Date  \
# 84704            NaN  VEHINV-MP150001-1617-00602            5/17/2016
#
#        Financier Name       Frame Number  Engine Number  \
# 84704          OTHERS  ME4JC651DGT232372  JC65ET0343884
#
#       Test Ride Vehicle Flag  Purchase type Enquiry Category  \
# 84704                    NaN        Finance       Individual
#
#       Number of Invoices
# 84704                  1
#
# [1 rows x 27 columns]

# %%
###############################################################################################################

# %%
# Changing the Datatype as per need 

df_bikes['Mobile No.'] = df_bikes['Mobile No.'].astype(int)
df_bikes['Mobile No.'] = df_bikes['Mobile No.'].astype(str)

# %%
df_bikes['Mobile No.'].shape , df_dealers['Help Line Numbers'].shape
# Out:
# ((358703,), (19914,))

# %%
# Removing the NULL values 

df_bikes_c = df_bikes[df_bikes['Mobile No.'].notna()]
df_dealers_c = df_dealers[df_dealers['Help Line Numbers'].notna()]

# %%
# Making set out of Dataframes 

rough1 =  set(df_dealers['Help Line Numbers'].tolist())
rough2 = set(df_bikes['Mobile No.'].tolist())

# %%
# Finding common values 

rough3 = rough1.intersection(rough2)
len(rough3)
# Out:
# 87

# %%
##############################################################################################

# %%
rough3 = list(rough3)

# %%
rough3[0]
# Out:
# '9997729105'

# %%
# Code to Check the dealers in Customer DB


df_bikes.loc[df_bikes['Mobile No.'] == '9829397355']
# Out:
#        Region Model Name Type Customer Id Customer First Name  \
# 331418  North   CB SHINE  2ID   1-1VI88KG            NARENDRA
# 359422  North   CB SHINE  2ID   1-1T1K8SD             KAILASH
#
#        Customer Last Name     Customer Type Customer Category  \
# 331418              MEENA  First Time Buyer        Individual
# 359422              MEENA  First Time Buyer        Individual
#
#         Customer Address Line 1 Customer Address Line 2  ... Invoice Number  \
# 331418    DHUNAI TEHSIL  NADBAI               BHARATPUR  ...            NaN
# 359422  VILLAGE - MEENA SEEMALA           TEHSIL SIKRAI  ...            NaN
#
#                       Reference No Invoice Created Date  Financier Name  \
# 331418  VEHINV-RJ110001-1617-00049             4/7/2016             NaN
# 359422  VEHINV-RJ110001-1617-00006             4/1/2016             NaN
#
#              Frame Number  Engine Number Test Ride Vehicle Flag  \
# 331418  ME4JC652BG7143639  JC65E70458067                    NaN
# ...

# %%
# Finding common values 

rough3 = rough1.intersection(rough2)
len(rough3)
# Out:
# 87

# %%
df_bikes.loc[df_bikes['Mobile No.'] == '7588166780']
# Out:
#        Region  Model Name Type Customer Id Customer First Name  \
# 254045   West    CB SHINE   ID   1-21WVSQ4           RAGHUNATH
# 306491   West    CB SHINE   ID   1-1Y24P3Y        PANDHARINATH
# 307069   West  DREAM YUGA  2ID   1-1Y0GIPA            RAVINDRA
# 350754   West    CB SHINE   ID   1-1U4171T                ASHA
#
#        Customer Last Name     Customer Type Customer Category  \
# 254045             MOKASE  First Time Buyer        Individual
# 306491            SALUNKE  First Time Buyer        Individual
# 307069              KADAM  First Time Buyer        Individual
# 350754             PALHAL  First Time Buyer        Individual
#
#                     Customer Address Line 1 Customer Address Line 2  ...  \
# 254045  M/POST- PISHOR SHAFEPUR  TL- KANNAD                     NaN  ...
# 306491                           A/P SANJUL               PHULAMBRI  ...
# 307069                              A/P N-6  AVISHKAR COLONY, CIDCO  ...
# ...

# %%
df_big = pd.concat([dataFrame1,dataFrame2, dataFrame3], ignore_index=True)
##############

for number in rough3:
  dataFrame4 = df_bikes.loc[df_bikes['Mobile No.'] == number]
  df_big = pd.concat([df_big , dataFrame4], ignore_index=True)

df_big
# Out:
#       Region      Model Name Type Customer Id Customer First Name  \
# 0    Central    CD 110 DREAM   ID   1-275DNBN            DEVENDRA
# 1    Central      DREAM YUGA  2ID   1-275236V              ASHISH
# 2    Central        CB SHINE  7ID   1-2610VGN               BHANU
# 3    Central      DREAM YUGA  2ID   1-260VPKR              NEERAJ
# 4      South        ACTIVA I  5ID   1-2NCUYND       MOHAMED NASAR
# ..       ...             ...  ...         ...                 ...
# 346     West        CB SHINE  2ID   1-1X9KCUQ            DNYANDEV
# 347     West        CB SHINE  2ID   1-1XF0NLN              MAROTI
# 348     West        CB SHINE   ID   1-1XFB36Y              SONAJI
# 349     West  CB125 SHINE SP  3ID   1-1XCEBG9               SURAJ
# 350     West            LIVO   ID   1-1XA8VJO              GOVIND
#
#     Customer Last Name     Customer Type Customer Category  \
# 0               SHARMA  First Time Buyer        Individual
# ...

# %%
############################################################################################################

# %%
############################################################################################################

# %%
# Removing the nan values of Dealer Code and Cust ID 
df_bikes_orig = df_bikes
df_dealers = df_dealers[df_dealers['Dealer Code'].notna()]
df_bikes = df_bikes[df_bikes['Phone No. Office'].notna()]

# %%
# Changing the Datatype as per need 

df_bikes['Phone No. Office'] = df_bikes['Phone No. Office'].astype(int)
df_bikes['Phone No. Office'] = df_bikes['Phone No. Office'].astype(str)
# Out:
# <ipython-input-322-6f3e032c57ff>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bikes['Phone No. Office'] = df_bikes['Phone No. Office'].astype(int)
# <ipython-input-322-6f3e032c57ff>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bikes['Phone No. Office'] = df_bikes['Phone No. Office'].astype(str)

# %%
df_bikes.shape , df_dealers.shape
# Out:
# ((11024, 27), (19914, 81))

# %%
set_dealers = set(df_dealers['Help Line Numbers'].tolist())
set_bikes = set(df_bikes['Phone No. Office'].tolist())

# %%
rough4 = set_dealers.intersection(set_bikes)

# %%
rough4
# Out:
# {'123456789', '8814980327', '8888819557'}

# %%
############################################################################################################

# %%
# Removing the nan values of Dealer Code and Cust ID 

df_dealers = df_dealers[df_dealers['Dealer Code'].notna()]
df_bikes = df_bikes[df_bikes['Phone No. Residence'].notna()]

# %%
# Changing the Datatype as per need 

df_bikes['Phone No. Residence'] = df_bikes['Phone No. Residence'].astype(int)
df_bikes['Phone No. Residence'] = df_bikes['Phone No. Residence'].astype(str)
# Out:
# <ipython-input-329-6ebc17c5dba5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bikes['Phone No. Residence'] = df_bikes['Phone No. Residence'].astype(int)
# <ipython-input-329-6ebc17c5dba5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bikes['Phone No. Residence'] = df_bikes['Phone No. Residence'].astype(str)

# %%
df_bikes.shape , df_dealers.shape
# Out:
# ((1932, 27), (19914, 81))

# %%
set_dealers = set(df_dealers['Help Line Numbers'].tolist())
set_bikes = set(df_bikes['Phone No. Residence'].tolist())

# %%
rough5 = set_dealers.intersection(set_bikes)
rough5
# Out:
# {'8275302645'}

# %%
############################################################################################################

# %%
set_dealers = set(df_dealers['Customer Care No'].tolist())
set_bikes = set(df_bikes['Phone No. Residence'].tolist())

# %%
rough6 = set_dealers.intersection(set_bikes)
rough6
# Out:
# set()

# %%
############################################################################################################

# %%
set_dealers = set(df_dealers['Service Contact Numbers'].tolist())
set_bikes = set(df_bikes['Mobile No.'].tolist())

# %%
rough7 = set_dealers.intersection(set_bikes)
rough7
# Out:
# {'8059900601'}

# %%
set_dealers = set(df_dealers['Service Contact Numbers'].tolist())
set_bikes = set(df_bikes['Phone No. Residence'].tolist())
rough8 = set_dealers.intersection(set_bikes)
rough8
# Out:
# set()

# %%
len(rough1),len(rough2),len(rough3)
# Out:
# (3031, 345628, 87)

# %%
###############################################################################################################

# %%
len(rough4),len(rough5),len(rough6),len(rough7)
# Out:
# (3, 1, 0, 1)

# %%
rough6 = rough4.union(rough5)
roughFinal = rough6.union(rough7)

len(roughFinal)
# Out:
# 5

# %%
351

# %%
for number in roughFinal:
  dataFrame4 = df_bikes_orig.loc[df_bikes_orig['Mobile No.'] == number]
  df_big = pd.concat([df_big , dataFrame4], ignore_index=True)

df_big
# Out:
#       Region      Model Name Type Customer Id Customer First Name  \
# 0    Central    CD 110 DREAM   ID   1-275DNBN            DEVENDRA
# 1    Central      DREAM YUGA  2ID   1-275236V              ASHISH
# 2    Central        CB SHINE  7ID   1-2610VGN               BHANU
# 3    Central      DREAM YUGA  2ID   1-260VPKR              NEERAJ
# 4      South        ACTIVA I  5ID   1-2NCUYND       MOHAMED NASAR
# ..       ...             ...  ...         ...                 ...
# 394    North            LIVO   ID   1-1TYY2HE        RAKESH KUMAR
# 395     West        CB SHINE   ID   1-2F3VVOC               VIJAY
# 396     West        CB SHINE   ID   1-280FP8T           BASAVARAJ
# 397     West  CB125 SHINE SP   ID   1-23HKM9Q           ABHAYSING
# 398     West        CB SHINE   ID   1-1ZTSNMI             RAMAJAN
#
#        Customer Last Name     Customer Type Customer Category  \
# 0                  SHARMA  First Time Buyer        Individual
# ...

# %% [markdown]
# SO WE HAVE 350 DIFFERENT USERS WITH UNIQUE CUSTOMER ID

# %%
gb1 = df_big.groupby('Customer Id')
gb1.first()
# Out:
#             Region      Model Name Type        Customer First Name  \
# Customer Id
# 1-1QJ9YVO     West      ACTIVA 125   ID                     TAUSIF
# 1-1SMYNR1     West        CB SHINE   ID                    PRADEEP
# 1-1SNSBEL     West      ACTIVA 125   ID  YASH MOTORS(NASHTE HONDA)
# 1-1SQXI69     West  CB125 SHINE SP  3ID                      DILIP
# 1-1T0ZBFP    North    CD 110 DREAM   ID                   AMARJEET
# ...            ...             ...  ...                        ...
# 1-2O3SY9B     West      CB UNICORN  7ID                    SANTOSH
# 1-2O4HG4B    South      DREAM YUGA  2ID                 MAHALINGAM
# 1-2O4YDEO    South            LIVO   ID           DAKSHINA MOORTHY
# 1-2O58PN9     West  CB125 SHINE SP   ID           SHAIKH ANISODDIN
# 1-2OBHF1L     West      ACTIVA 125   ID               HARSHWARDHAN
#
#                                 Customer Last Name     Customer Type  \
# Customer Id
# ...

# %%
count = df_big['Mobile No.'].value_counts()
count
# Out:
# 123456789       86
# 8007999326      25
# 9997729105      18
# 9551024000      15
# 9673098371      14
#                 ..
# 8129460555       1
# 9174094021.0     1
# 9942682865.0     1
# 9043648876.0     1
# 8059900601       1
# Name: Mobile No., Length: 120, dtype: int64

# %%
df_big.loc[df_big['Mobile No.'] == '8007999326']
# Out:
#     Region      Model Name Type Customer Id Customer First Name  \
# 297   West      ACTIVA 125   ID   1-2OBHF1L        HARSHWARDHAN
# 298   West        CB SHINE   ID   1-2LSXF89               VIJAY
# 299   West         AVIATOR  4ID   1-2IQUGE2                ARUN
# 300   West      DREAM YUGA  2ID   1-2IMIZ6H              SATISH
# 301   West        CB SHINE   ID   1-2GM7U3T            SURENDRA
# 302   West      DREAM YUGA  2ID   1-2FFBA86             BABULAL
# 303   West        CB SHINE   ID   1-2CM1B8Z         CHANDRAKALA
# 304   West        ACTIVA I  5ID   1-2939F99             RAJRANI
# 305   West        CB SHINE   ID   1-293R3NT               DIPAK
# 306   West            LIVO  3ID   1-2940MOF           RAMCHARAN
# 307   West        CB SHINE   ID   1-268A2QG               AKASH
# 308   West            LIVO   ID   1-24DFGZW              NAGESH
# 309   West      ACTIVA 125   ID   1-238JJS7             ASHWINI
# 310   West        CB SHINE  2ID   1-23732UX            RAJENDRA
# ...

# %%
# This code helps in deleting entries of the DataFrame

'''df = df_bikes

for number in rough3:
  index_names = df[ df['Mobile No.'] == number ].index
  df.drop(index_names, inplace = True)

df.shape 
'''
# Out:
# "df = df_bikes\n\nfor number in rough3:\n  index_names = df[ df['Mobile No.'] == number ].index\n  df.drop(index_names, inplace = True)\n\ndf.shape \n"
